# %% [markdown]
# # MAGIC + LST-1 data quality

# %%
import pandas as pd
import numpy as np
import glob
import os
import math
import matplotlib.pyplot as plt
import re
from ctapipe.io import read_table
from astropy.table import Table

from astropy.coordinates import SkyCoord, AltAz, angular_separation
import astropy.units as u

from gammapy.data import DataStore, EventList
from astropy.io import fits
from astropy.stats import circmean
from matplotlib.ticker import FuncFormatter
from matplotlib.colors import Normalize

from scipy.optimize import curve_fit

# %%
# ===========
#   INPUT
# ===========

# DL1Stereo/Merged data path 
# ----------------------------
dl1_stereo_1 = "/fefs/aswg/LST1MAGIC/data/v0.5.0/*/DL1Stereo/Merged/2022121[7-8]/*.h5"
dl1_stereo_2 = "/fefs/aswg/LST1MAGIC/data/v0.5.0/*/DL1Stereo/Merged/20240212/*.h5"
dl1_stereo_3 = "/fefs/aswg/LST1MAGIC/data/v0.6.1/*/DL1Stereo/Merged/202511*/*.h5"
# ----------------------------

paths=[dl1_stereo_1, dl1_stereo_2, dl1_stereo_3]
dl1s_files = [x for y in paths for x in glob.glob(y)]

print(f"{len(dl1s_files)} files found.")
# Out:
# 107 files found.

# %% [markdown]
# # Joint data quality method based on the mean event rate of stereoscopically reconstructed background events, calculated for each individual run.

# %% [markdown]
# Details of the method are described in
# https://magic.mpp.mpg.de/RS/viewforum.php?f=734
# and
# https://xwiki.lstmagic.pic.es/bin/view/Paper/Automatized%20joint%20MAGIC%2BLST-1%20analysis%20pipeline?srid=yzQiX8kz

# %% [markdown]
# # Event rate from dl1 stereo files

# %%
all_df1s = []

for file in dl1s_files:
    filename = os.path.basename(file)
    run_id_str = filename.split("Run")[-1].split(".")[0]
    run_id = int(run_id_str.lstrip("0"))

    events_table = read_table(file, "/events/parameters")

    df = pd.DataFrame(
        {
            "event_id": events_table["event_id_lst"],
            "timestamp": events_table["timestamp"],
            "zenith": 90 - events_table["alt"],
            "azimuth": events_table["pointing_az"],
            "run_id": run_id,
        }
    )

    df_unique = df[~df["event_id"].duplicated(keep="first")].reset_index(drop=True)
    all_df1s.append((df_unique, run_id))

# %%
run_ids_list = []

n_files = len(all_df1s)
n_cols = 2
n_rows = math.ceil(n_files / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(12, 4 * n_rows), sharex=False)
axes = axes.flatten()

for idx, (df, run_id) in enumerate(all_df1s):

    event_rates = []

    df["timestamp"] = pd.to_datetime(df["timestamp"], unit="s")
    min_time = df["timestamp"].min()
    df["time_since_start"] = (df["timestamp"] - min_time).dt.total_seconds()
    times = df["time_since_start"].values

    if times.size == 0:
        print(f"Run {run_id} has 0 events.")
        continue

    run_ids_list.append(run_id)
    bin_width = 1  # [s]
    bins = np.arange(0, times.max() + bin_width, bin_width)
    counts, bin_edges = np.histogram(times, bins=bins)
    event_rate = counts / bin_width
    event_rates.append(event_rate)
    
    ax = axes[idx]
    ax.step(bin_edges[:-1], event_rate, where="mid")
    #  ax.axvline(x=300, color="green", linestyle="--")  # 300s = 5 min
    ax.set_xlabel("Time since start of run [s]")
    ax.set_ylabel("Event rate [1/s]")
    ax.set_ylim(0, 200)

    ax.set_title(f"Event rate vs time for the Run {run_id}", fontsize=10)
    ax.grid()

for idx in range(n_files, n_rows * n_cols):
    fig.delaxes(axes[idx])


plt.tight_layout()
plt.show()

# %% [markdown]
# # Event rate vs zenith angle (+zenith cut)

# %%
# ===========
#   INPUT
# ===========

# zenith cut [deg]

zenith_limit = 60

# %%
period_ranges = {
    #MAGIC observartion periods
    "ST0316A": [("2020-10-24", "2021-09-29"),],
    "ST0317A": [("2021-12-30", "2022-06-09"),],
    "ST0318A": [("2022-06-10", "2022-08-31"),("2022-12-15", "2023-01-06"),],
    "M20318A": [("2022-09-04", "2022-12-14"),],
    "ST0319A": [("2023-01-07", "2023-03-09"),],
    "ST0320A": [("2023-03-10", "2024-05-18"),],
    "ST0321A": [("2024-05-19", "2026-01-01"),],
}

for period in period_ranges.keys():

    globals()[period] = []
    globals()[f"{period}_mean_event_rates_list"] = []
    globals()[f"{period}_zenith_median_list"] = []
    globals()[f"{period}_az_mean_list"] = []

period_ranges_dt = {
    period: [
        (pd.to_datetime(start), pd.to_datetime(end))
        for start, end in ranges
    ]
    for period, ranges in period_ranges.items()
}

for df, run_id in all_df1s:

    timestamps = pd.to_datetime(
        df["timestamp"],
        unit="s"
    )

    if len(timestamps) == 0:
        continue

    t0 = timestamps.min()
    times = (timestamps - t0).dt.total_seconds().to_numpy()

    start_run_date = t0
    bin_width = 1
    bins = np.arange(0, times.max() + bin_width, bin_width)
    counts, _ = np.histogram(times,bins=bins)
    event_rate_per_bin = counts / bin_width
    event_rate_nonzero = event_rate_per_bin[event_rate_per_bin > 0]

    if event_rate_nonzero.size == 0:
        continue

    mean_event_rate = np.mean(event_rate_nonzero)
    zenith = df["zenith"].to_numpy(dtype=float)

    zenith_median = np.nanmedian(zenith)

    if np.isnan(zenith_median):
        continue

    if zenith_median > zenith_limit:
        continue

    azimuth = df["azimuth"].to_numpy(dtype=float)
    azimuth = azimuth[np.isfinite(azimuth)]

    if azimuth.size == 0:
        continue

    az_mean_rad = circmean(azimuth)
    az_mean = np.rad2deg(az_mean_rad) % 360

    period_found = None

    for period, ranges in period_ranges_dt.items():

        for start_date, end_date in ranges:

            if start_date <= start_run_date < end_date:
                period_found = period
                break

        if period_found is not None:
            break

    if period_found is None:
        continue

    globals()[period_found].append(int(run_id))
    globals()[f"{period_found}_mean_event_rates_list"].append(float(mean_event_rate))
    globals()[f"{period_found}_zenith_median_list"].append(float(zenith_median))
    globals()[f"{period_found}_az_mean_list"].append(float(az_mean))

# %%
def sort_runs_by_zenith(run_ids, zeniths, rates, azimuths):
    data_sorted = sorted(
        zip(zeniths, azimuths, run_ids, rates),
        key=lambda x: x[0]
    )
    return data_sorted


for label, run_ids, zeniths, rates, azimuths in [
    ("ST0316A", ST0316A, ST0316A_zenith_median_list, ST0316A_mean_event_rates_list, ST0316A_az_mean_list),
    ("ST0317A", ST0317A, ST0317A_zenith_median_list, ST0317A_mean_event_rates_list, ST0317A_az_mean_list),
    ("ST0318A", ST0318A, ST0318A_zenith_median_list, ST0318A_mean_event_rates_list, ST0318A_az_mean_list),
    ("M20318A", M20318A, M20318A_zenith_median_list, M20318A_mean_event_rates_list, M20318A_az_mean_list),
    ("ST0319A", ST0319A, ST0319A_zenith_median_list, ST0319A_mean_event_rates_list, ST0319A_az_mean_list),
    ("ST0320A", ST0320A, ST0320A_zenith_median_list, ST0320A_mean_event_rates_list, ST0320A_az_mean_list),
    ("ST0321A", ST0321A, ST0321A_zenith_median_list, ST0321A_mean_event_rates_list, ST0321A_az_mean_list),
]:
    print(f"\n{label}:")

    for zen, azi, rid, rate in sort_runs_by_zenith(
        run_ids,
        zeniths,
        rates,
        azimuths
    ):
        print(
            f"Run {rid}, "
            f"Zenith = {zen:.2f}, "
            f"Azimuth = {azi:.2f}, "
            f"Mean rate = {rate:.2f} 1/s"
        )
# Out:
# ST0316A:
#
# ST0317A:
#
# ST0318A:
# Run 11465, Zenith = 6.65, Azimuth = 181.96, Mean rate = 90.26 1/s
# Run 11464, Zenith = 7.85, Azimuth = 155.48, Mean rate = 90.52 1/s
# Run 11466, Zenith = 8.40, Azimuth = 215.34, Mean rate = 92.84 1/s
# Run 11482, Zenith = 9.05, Azimuth = 1.57, Mean rate = 60.76 1/s
# Run 11434, Zenith = 9.20, Azimuth = 139.60, Mean rate = 89.36 1/s
# Run 11463, Zenith = 10.06, Azimuth = 129.84, Mean rate = 89.14 1/s
# Run 11467, Zenith = 10.26, Azimuth = 232.98, Mean rate = 92.59 1/s
# Run 11481, Zenith = 10.50, Azimuth = 18.41, Mean rate = 61.56 1/s
# Run 11480, Zenith = 11.44, Azimuth = 31.75, Mean rate = 62.99 1/s
# Run 11433, Zenith = 13.59, Azimuth = 116.49, Mean rate = 88.71 1/s
# Run 11479, Zenith = 13.99, Azimuth = 44.13, Mean rate = 63.05 1/s
# Run 11468, Zenith = 14.29, Azimuth = 244.29, Mean rate = 94.11 1/s
# Run 11469, Zenith = 17.06, Azimuth = 251.82, Mean rate = 94.61 1/s
# Run 11432, Zenith = 17.39, Azimuth = 110.16, Mean rate = 89.99 1/s
# Run 11470, Zenith = 20.92, Azimuth = 255.79, Mean rate = 96.59 1/s
# Run 11431, Zenith = 22.09, Azimuth = 102.06, Mean rate = 91.67 1/s
# Run 11430, Zenith = 25.62, Azimuth = 99.74, Mean rate = 90.96 1/s
#
# M20318A:
#
# ST0319A:
#
# ST0320A:
# Run 16750, Zenith = 8.45, Azimuth = 65.39, Mean rate = 102.00 1/s
# Run 16749, Zenith = 12.38, Azimuth = 67.90, Mean rate = 130.50 1/s
# Run 16748, Zenith = 16.14, Azimuth = 72.87, Mean rate = 134.83 1/s
# Run 16740, Zenith = 18.09, Azimuth = 55.15, Mean rate = 133.63 1/s
# Run 16747, Zenith = 21.20, Azimuth = 74.47, Mean rate = 133.86 1/s
# Run 16739, Zenith = 21.53, Azimuth = 56.81, Mean rate = 134.80 1/s
# Run 16746, Zenith = 25.04, Azimuth = 75.76, Mean rate = 121.21 1/s
# Run 16745, Zenith = 28.93, Azimuth = 73.87, Mean rate = 131.53 1/s
# Run 16744, Zenith = 31.01, Azimuth = 73.75, Mean rate = 136.83 1/s
# Run 16736, Zenith = 44.95, Azimuth = 273.64, Mean rate = 127.76 1/s
# Run 16737, Zenith = 50.16, Azimuth = 275.47, Mean rate = 126.31 1/s
#
# ST0321A:
# Run 23034, Zenith = 8.00, Azimuth = 198.27, Mean rate = 110.57 1/s
# Run 23033, Zenith = 8.06, Azimuth = 163.07, Mean rate = 109.58 1/s
# Run 23057, Zenith = 8.08, Azimuth = 186.86, Mean rate = 116.43 1/s
# Run 23058, Zenith = 8.64, Azimuth = 210.11, Mean rate = 115.19 1/s
# Run 23094, Zenith = 9.23, Azimuth = 227.50, Mean rate = 84.50 1/s
# Run 23035, Zenith = 9.71, Azimuth = 224.42, Mean rate = 109.14 1/s
# Run 23095, Zenith = 11.69, Azimuth = 236.20, Mean rate = 85.82 1/s
# Run 23059, Zenith = 12.19, Azimuth = 234.82, Mean rate = 118.64 1/s
# Run 23053, Zenith = 13.04, Azimuth = 345.91, Mean rate = 75.81 1/s
# Run 23036, Zenith = 13.69, Azimuth = 237.65, Mean rate = 112.42 1/s
# Run 22944, Zenith = 14.01, Azimuth = 239.47, Mean rate = 119.21 1/s
# Run 22947, Zenith = 15.31, Azimuth = 228.30, Mean rate = 88.94 1/s
# Run 23060, Zenith = 15.33, Azimuth = 246.09, Mean rate = 116.17 1/s
# Run 23037, Zenith = 17.10, Azimuth = 247.93, Mean rate = 115.22 1/s
# Run 22945, Zenith = 18.15, Azimuth = 249.85, Mean rate = 120.36 1/s
# Run 22948, Zenith = 18.52, Azimuth = 236.41, Mean rate = 90.22 1/s
# Run 22946, Zenith = 21.91, Azimuth = 255.32, Mean rate = 120.80 1/s
# Run 23038, Zenith = 22.07, Azimuth = 255.45, Mean rate = 117.42 1/s
# Run 23039, Zenith = 24.69, Azimuth = 261.00, Mean rate = 122.77 1/s
# Run 23040, Zenith = 28.91, Azimuth = 263.38, Mean rate = 125.93 1/s
# Run 23098, Zenith = 30.16, Azimuth = 152.70, Mean rate = 129.16 1/s
# Run 23031, Zenith = 33.74, Azimuth = 179.67, Mean rate = 131.96 1/s
# Run 23008, Zenith = 33.74, Azimuth = 182.28, Mean rate = 121.76 1/s
# Run 23007, Zenith = 34.25, Azimuth = 175.02, Mean rate = 108.87 1/s
# Run 23030, Zenith = 34.28, Azimuth = 174.43, Mean rate = 133.59 1/s
# Run 23055, Zenith = 34.38, Azimuth = 188.51, Mean rate = 149.57 1/s
# Run 23032, Zenith = 34.69, Azimuth = 186.37, Mean rate = 134.29 1/s
# Run 23056, Zenith = 34.90, Azimuth = 193.65, Mean rate = 153.91 1/s
# Run 23054, Zenith = 34.98, Azimuth = 166.35, Mean rate = 146.25 1/s
# Run 22917, Zenith = 36.60, Azimuth = 156.98, Mean rate = 132.85 1/s
# Run 22916, Zenith = 38.31, Azimuth = 150.43, Mean rate = 132.05 1/s
# Run 23073, Zenith = 39.60, Azimuth = 215.42, Mean rate = 156.60 1/s
# Run 22915, Zenith = 40.89, Azimuth = 144.23, Mean rate = 130.99 1/s
# Run 23074, Zenith = 41.95, Azimuth = 218.88, Mean rate = 158.33 1/s
# Run 22914, Zenith = 42.21, Azimuth = 139.00, Mean rate = 129.88 1/s
# Run 22864, Zenith = 43.48, Azimuth = 137.44, Mean rate = 136.91 1/s
# Run 22833, Zenith = 43.95, Azimuth = 337.33, Mean rate = 118.18 1/s
# Run 22927, Zenith = 44.44, Azimuth = 185.25, Mean rate = 139.04 1/s
# Run 22911, Zenith = 44.45, Azimuth = 355.36, Mean rate = 127.19 1/s
# Run 22834, Zenith = 44.88, Azimuth = 337.09, Mean rate = 127.37 1/s
# Run 22910, Zenith = 45.00, Azimuth = 357.33, Mean rate = 127.45 1/s
# Run 22912, Zenith = 45.13, Azimuth = 354.03, Mean rate = 125.95 1/s
# Run 22928, Zenith = 45.24, Azimuth = 193.26, Mean rate = 140.31 1/s
# Run 22835, Zenith = 45.24, Azimuth = 335.42, Mean rate = 125.03 1/s
# Run 22863, Zenith = 45.78, Azimuth = 133.29, Mean rate = 136.40 1/s
# Run 22913, Zenith = 45.79, Azimuth = 351.72, Mean rate = 123.17 1/s
# Run 22929, Zenith = 45.99, Azimuth = 199.46, Mean rate = 144.62 1/s
# Run 23084, Zenith = 46.21, Azimuth = 6.09, Mean rate = 71.57 1/s
# Run 23041, Zenith = 46.22, Azimuth = 198.69, Mean rate = 143.94 1/s
# Run 22909, Zenith = 46.35, Azimuth = 335.18, Mean rate = 124.00 1/s
# Run 22952, Zenith = 47.10, Azimuth = 8.73, Mean rate = 123.09 1/s
# Run 22820, Zenith = 47.11, Azimuth = 334.63, Mean rate = 119.60 1/s
# Run 23082, Zenith = 47.27, Azimuth = 8.04, Mean rate = 135.21 1/s
# Run 23083, Zenith = 47.47, Azimuth = 7.35, Mean rate = 132.76 1/s
# Run 23081, Zenith = 47.51, Azimuth = 8.64, Mean rate = 136.42 1/s
# Run 22862, Zenith = 47.52, Azimuth = 131.31, Mean rate = 135.01 1/s
# Run 23042, Zenith = 47.69, Azimuth = 204.40, Mean rate = 145.60 1/s
# Run 23080, Zenith = 47.82, Azimuth = 9.34, Mean rate = 135.64 1/s
# Run 22951, Zenith = 48.15, Azimuth = 9.01, Mean rate = 120.65 1/s
# Run 22950, Zenith = 48.36, Azimuth = 10.39, Mean rate = 119.40 1/s
# Run 22930, Zenith = 48.45, Azimuth = 205.42, Mean rate = 144.22 1/s
# Run 22821, Zenith = 48.63, Azimuth = 334.30, Mean rate = 121.02 1/s
# Run 23079, Zenith = 48.64, Azimuth = 10.88, Mean rate = 137.03 1/s
# Run 23043, Zenith = 48.98, Azimuth = 209.52, Mean rate = 150.13 1/s
# Run 23078, Zenith = 49.10, Azimuth = 11.60, Mean rate = 138.09 1/s
# Run 22861, Zenith = 49.14, Azimuth = 128.93, Mean rate = 129.45 1/s
# Run 22931, Zenith = 49.75, Azimuth = 210.34, Mean rate = 141.16 1/s
# Run 22949, Zenith = 49.78, Azimuth = 12.53, Mean rate = 124.03 1/s
# Run 22822, Zenith = 50.20, Azimuth = 332.42, Mean rate = 118.20 1/s
# Run 22860, Zenith = 50.83, Azimuth = 125.21, Mean rate = 129.13 1/s
# Run 22823, Zenith = 51.86, Azimuth = 332.35, Mean rate = 104.65 1/s
# Run 22859, Zenith = 52.40, Azimuth = 123.31, Mean rate = 128.27 1/s
# Run 22824, Zenith = 53.06, Azimuth = 332.01, Mean rate = 110.93 1/s
# Run 22858, Zenith = 53.84, Azimuth = 122.33, Mean rate = 125.75 1/s

# %% [markdown]
# The runs were divided into three ranges according to the NSB level [p.e.]:
# dark [0, 1.75], medium (1.75, 2.25], and bright (2.25, 3].

# %%
LST_database = "/fefs/aswg/workspace/elisa.visentin/auto_MCP_PR/observations_LST.h5"
LST_database_key = "joint_obs"
df_LST = pd.read_hdf(LST_database, key=LST_database_key)

nsb_values = []
runs_dark_nsb = []
runs_medium_nsb = []
runs_bright_nsb = []

df_LST["LST1_run"] = df_LST["LST1_run"].astype(int)

for run_id in run_ids_list:

    match = df_LST[df_LST["LST1_run"] == run_id]

    if not match.empty:
        nsb = match["nsb"].iloc[0]
    else:
        nsb = None
    nsb_values.append(nsb)

    if nsb is None or pd.isna(nsb):
        continue

    if nsb <= 1.75:
        runs_dark_nsb.append(run_id)

    elif nsb <= 2.25:
        runs_medium_nsb.append(run_id)

    else:
        runs_bright_nsb.append(run_id)

# %%
# Do not change the values!
# Theoretical model for event rate based on proton showers
# M20318A we treat separately, since due to monoscopic observations od MAGIC-II

def rate_model(theta_deg, phi_deg, special_m20318a=False):
    th = np.deg2rad(theta_deg)
    ph = np.deg2rad(phi_deg)

    if special_m20318a:
        A0 = 171.0
        C  = 451.0
        c0 = 0.815
        b1 = 46.8
        b2 = +8.9  
        phi0 = np.deg2rad(93.0)
    else:
        A0 = 102.0
        C  = 286.0
        c0 = 0.799
        b1 = 6.24
        b2 = -25.4
        phi0 = np.deg2rad(83.0)

    return (
        A0
        - C * (np.cos(th) - c0)**2
        + np.sin(th)**2 * (
            b1 * np.sin(ph - phi0)
            + b2 * np.sin(2.0 * (ph - phi0))
        )
    )

# %%
# Do not change the values!
# a_period - the ratio of the event rate from observational data to the expected proton rate from model 
# (rate_model) for individual analysis periods 

a_period = {
    "ST0316A": 135.26,
    "ST0317A": 108.88,
    "ST0318A": 108.88,
    "M20318A": 100.99,
    "ST0320A": 119.12,
    "ST0321A": 121.88,
}

# Tolerance threshold for each NSB range

tolerance_threshold = {
    "dark": 0.85,
    "medium": 0.765,
    "bright": 0.663,
}

# %%
periods = [
    (
        period,
        globals()[period],
        globals()[f"{period}_zenith_median_list"],
        globals()[f"{period}_mean_event_rates_list"],
        globals()[f"{period}_az_mean_list"],
    )
    for period in period_ranges.keys()
]

for label, run_ids, zeniths, rates, azimuths in periods:
    
    if len(run_ids) == 0:
        #print(f"{label}: no runs - skipping plot")
        continue

    dark_x = []
    dark_y = []

    medium_x = []
    medium_y = []

    bright_x = []
    bright_y = []

    #print(f"\n{label}:")

    special = (label == "M20318A")

    for zen, azi, rid, rate_data in sort_runs_by_zenith(
        run_ids,
        zeniths,
        rates,
        azimuths,
    ):

        cos_zen = np.cos(np.deg2rad(zen))

        rate_mod = rate_model(zen, azi, special_m20318a=special)

        # R_data / R_model [%]
        ratio = 100.0 * rate_data / rate_mod
        
        # print details (optional)
        """
        print(
            f"Run {rid}, "
            f"Zenith = {zen:.2f}, "
            f"Azimuth = {azi:.2f}, "
            f"R_data = {rate_data:.2f}, "
            f"R_model = {rate_mod:.2f}, "
            f"R_data/R_model = {ratio:.2f}%"
        )
        """

        if rid in runs_dark_nsb:
            dark_x.append(cos_zen)
            dark_y.append(ratio)

        elif rid in runs_medium_nsb:
            medium_x.append(cos_zen)
            medium_y.append(ratio)

        elif rid in runs_bright_nsb:
            bright_x.append(cos_zen)
            bright_y.append(ratio)

        else:
            print(
                f"Run {rid} "
                f"is not present in any NSB list"
            )

    plt.figure(figsize=(6, 4))

    plt.scatter(
        dark_x,
        dark_y,
        marker="o",
        s=25,
        label="Dark NSB",
    )

    plt.scatter(
        medium_x,
        medium_y,
        marker="^",
        s=25,
        label="Medium NSB",
    )

    plt.scatter(
        bright_x,
        bright_y,
        marker="s",
        s=25,
        label="Bright NSB",
    )

    plt.axhline(
        a_period[label],
        linestyle="--",
        linewidth=1,
        label=fr"$a_{{period, dark}} = {a_period[label]:.1f}\%$",
    )

    plt.xlabel(r"$\cos(\theta)$")
    plt.ylabel(r"$R_{\mathrm{data}}/R_{\mathrm{model}}$ [%]")
    plt.ylim(0, 200)

    plt.title(label)

    plt.grid(alpha=0.3)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
nsb_style = {
    "dark": {
        "color": "tab:blue",
        "marker": "o",
        "label": "NSB [0, 1.75]"
    },

    "medium": {
        "color": "tab:orange",
        "marker": "^",
        "label": "NSB (1.75, 2.25]"
    },

    "bright": {
        "color": "tab:green",
        "marker": "s",
        "label": "NSB (2.25, 3.0]"
    }
}


data_nsb = {
    "dark": {
        "x": [],
        "y": [],
        "runs": [],
        "periods": []
    },

    "medium": {
        "x": [],
        "y": [],
        "runs": [],
        "periods": []
    },

    "bright": {
        "x": [],
        "y": [],
        "runs": [],
        "periods": []
    }
}

for label, run_ids, zeniths, rates, azimuths in periods:

    if len(run_ids) == 0:
        continue

    special = (label == "M20318A")

    for zen, azi, rid, rate_data in sort_runs_by_zenith(
        run_ids,
        zeniths,
        rates,
        azimuths
    ):

        zenith_deg = zen

        # model rate
        rate_mod = rate_model(zen, azi, special_m20318a=special)

        # R_data / R_model [%]
        ratio = 100.0 * rate_data / rate_mod

        # normalized R_data/ R_model
        normalized_ratio = ratio / a_period[label]

        if rid in runs_dark_nsb:

            data_nsb["dark"]["x"].append(zen)
            data_nsb["dark"]["y"].append(normalized_ratio)
            data_nsb["dark"]["runs"].append(rid)
            data_nsb["dark"]["periods"].append(label)

        elif rid in runs_medium_nsb:

            data_nsb["medium"]["x"].append(zen)
            data_nsb["medium"]["y"].append(normalized_ratio)
            data_nsb["medium"]["runs"].append(rid)
            data_nsb["medium"]["periods"].append(label)

        elif rid in runs_bright_nsb:

            data_nsb["bright"]["x"].append(zen)
            data_nsb["bright"]["y"].append(normalized_ratio)
            data_nsb["bright"]["runs"].append(rid)
            data_nsb["bright"]["periods"].append(label)

for nsb in ["dark", "medium", "bright"]:

    x = np.asarray(data_nsb[nsb]["x"])
    y = np.asarray(data_nsb[nsb]["y"])
    runs = np.asarray(data_nsb[nsb]["runs"])
    period_labels = np.asarray(data_nsb[nsb]["periods"])

    if len(x) == 0:
        print()
        print(f"\n{nsb.upper()} NSB: no runs")
        continue

    threshold = tolerance_threshold[nsb]

    plt.figure(figsize=(9, 6))

    # Tolerance zone:
    plt.axhspan(
        threshold,
        2.0,
        color="grey",
        alpha=0.25,
        label="Tolerance zone"
    )

    plt.scatter(
        x,
        y,
        color=nsb_style[nsb]["color"],
        marker=nsb_style[nsb]["marker"],
        label=nsb_style[nsb]["label"]
    )

    plt.xlabel(r"zenith [deg]")
    plt.ylabel(r"Normalized $R_{\mathrm{data}}/R_{\mathrm{model}}$" )

    plt.title(nsb_style[nsb]["label"])

    plt.ylim(0, 2)

    plt.grid(alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.show()

    tolerance_mask = (y >= threshold)
    outside_mask = ~tolerance_mask
    
    print(f"\n{nsb.upper()} NSB - runs in tolerance zone:")

    if np.any(tolerance_mask):

        indices = np.where(tolerance_mask)[0]

        for i in indices:
            print(f"{runs[i]}, ", end="")
            # print details - optional
            """
            print(
                f"Run {runs[i]}, "
                f"Period = {period_labels[i]}, "
                f"zenith = {x[i]:.3f}, "
                f"normalized R_data/R_model = {y[i]:.3f}"
            )
            """
    else:
        print("No runs in tolerance zone.")
        
    print()
        
    print(f"\n{nsb.upper()} NSB - runs outside tolerance zone:")

    if np.any(outside_mask):

        indices = np.where(outside_mask)[0]

        for i in indices:
            print(f"{runs[i]}, ", end="")
            # print details - optional
            """
            print(
                f"Run {runs[i]}, "
                f"Period = {period_labels[i]}, "
                f"zenith = {x[i]:.3f}, "
                f"normalized R_data/R_model = {y[i]:.3f}"
            )
            """

        print()

    else:
        print("No runs outside tolerance zone.")
# Out:
# DARK NSB - runs in tolerance zone:
# 11465, 11464, 11466, 11434, 11463, 11467, 11433, 11468, 11469, 11432, 11470, 11431, 11430, 16750, 16749, 16748, 16740, 16747, 16739, 16746, 16745, 16744, 16736, 16737, 23034, 23033, 23057, 23058, 23035, 23059, 23036, 22944, 23060, 23037, 22945, 22946, 23038, 23040, 23098, 23031, 23008, 23007, 23030, 23055, 23032, 23056, 23054, 22917, 22916, 23073, 22915, 23074, 22914, 22864, 22833, 22911, 22834, 22910, 22912, 22835, 22863, 22913, 22909, 22952, 22820, 23082, 23083, 23081, 22862, 23080, 22951, 22950, 22821, 23079, 23078, 22861, 22949, 22822, 22860, 22823, 22859, 22824, 22858,
#
# DARK NSB - runs outside tolerance zone:
# 23095, 22947, 22948, 23084,
# MEDIUM NSB - runs in tolerance zone:
# 23039, 22927, 22928, 22929, 23041, 23042, 23043,
#
# MEDIUM NSB - runs outside tolerance zone:
# 11482, 11481, 11480, 11479, 23094, 23053,
# BRIGHT NSB - runs in tolerance zone:
# 22930, 22931,
#
# BRIGHT NSB - runs outside tolerance zone:
# No runs outside tolerance zone.

# %% [markdown]
# WARNING! Runs above ~1.5 are still in the tolerance zones however we advise a double check of the runs to understand high rates. It is worth to check the trigger settings.

# %% [markdown]
# # Zenith range per run

# %%
zenith_run_ids = []
zenith_min = []
zenith_max = []

for filepath in dl1s_files:
    match = re.search(r'Run(\d+)', os.path.basename(filepath))
    if not match:
        continue

    run_id = int(match.group(1))

    try:
        df = pd.read_hdf(filepath, key="events/parameters")
        alt = df["pointing_alt"].dropna()

        if alt.empty:
            print(f"No valid pointing_alt values in the file {filepath}")
            continue

        alt_deg = alt * 180 / np.pi

        zmin = 90.0 - alt_deg.max()
        zmax = 90.0 - alt_deg.min()

        zenith_run_ids.append(run_id)
        zenith_min.append(zmin)
        zenith_max.append(zmax)

    except Exception as e:
        print(f"Error in the file {filepath}: {e}")
        continue

zenith_run_ids = np.array(zenith_run_ids)
zenith_min = np.array(zenith_min)
zenith_max = np.array(zenith_max)

sort_idx = np.argsort(zenith_run_ids)

zenith_run_ids = zenith_run_ids[sort_idx]
zenith_min = zenith_min[sort_idx]
zenith_max = zenith_max[sort_idx]

x_pos = np.arange(len(zenith_run_ids))
fig, ax = plt.subplots(figsize=(10, 6))

ax.vlines(
    x_pos,
    zenith_min,
    zenith_max,
    color="black",
    linewidth=1
)

ax.plot(x_pos, zenith_min, "bo")
ax.plot(x_pos, zenith_max, "bo")

ax.axhline(
    zenith_limit,
    color="red",
    linestyle="-",
    linewidth=2
)

ax.fill_between(
    x_pos,
    zenith_limit,
    90,
    color="red",
    alpha=0.2
)

ax.set_xticks(x_pos)
ax.set_xticklabels(
    zenith_run_ids,
    rotation=90,
    ha="right"
)

ax.set_xlabel("Run ID")
ax.set_ylabel("Zenith angle [deg]")
ax.set_title("Zenith angle range per run")

ax.grid(True, linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()

# %%
for r, mi, ma in zip(zenith_run_ids, zenith_min, zenith_max):
    print(f"{r}, {mi}, {ma}")
# Out:
# 11430, 23.684929562734027, 27.086981995880805
# 11431, 19.74191078408883, 23.92095805361147
# 11432, 15.131191887330289, 19.145723365441285
# 11433, 11.461706275757365, 15.284391066293935
# 11434, 7.166016488655089, 11.064120676233188
# 11463, 8.733841667934598, 11.013464477335944
# 11464, 7.071310296775408, 8.56135509822687
# 11465, 6.490556301394861, 6.821821215501174
# 11466, 7.54259150705343, 9.629115570432944
# 11467, 9.000703016502754, 11.887888382744109
# 11468, 12.868264887967442, 16.12064808691568
# 11469, 15.538378147053422, 18.968970532741423
# 11470, 19.96044432087409, 22.282236072373365
# 11479, 12.81516275135074, 14.742721010297586
# 11480, 10.455535565038417, 12.130954623798175
# 11481, 9.916619158647592, 10.911662237071312
# 11482, 8.917033246078901, 9.1013901965227
# 16736, 44.92511000639615, 45.28748234817268
# 16737, 50.05224230355072, 50.52932574505413
# 16739, 19.601848779000463, 22.969165614371477
# 16740, 16.52678075462711, 19.170414380175416
# 16744, 30.688973962163487, 30.84410681835959
# 16745, 27.086340773518124, 30.11422358828495
# 16746, 22.759823888688075, 26.956423529688188
# 16747, 18.831693148715644, 23.036898190027983
# 16748, 13.762237067649735, 17.909879077595107
# 16749, 10.079381483223528, 14.095465998926585
# 16750, 6.396737482357054, 9.707981712909856
# 22820, 46.4285501415299, 47.85191174334885
# 22821, 47.69076540093167, 49.60378038225347
# 22822, 49.36780547717, 51.092493196667185
# 22823, 51.658183506200146, 52.14169270018871
# 22824, 52.498686715294056, 53.69594686979587
# 22825, 66.0968571025858, 67.88440392979157
# 22826, 63.64610675493317, 65.41154870620969
# 22827, 60.99322785637559, 63.069345378638204
# 22833, 43.640309537781015, 44.30934878181834
# 22834, 44.29099369905201, 45.539275510676475
# 22835, 45.14741212947645, 45.36124045683389
# 22858, 53.24372411643699, 54.08624598634749
# 22859, 51.2946788106446, 53.161456605409946
# 22860, 50.46133682539648, 50.809439132102014
# 22861, 48.47113189261774, 50.914620155762044
# 22862, 46.935961903359896, 47.7535806716957
# 22863, 44.43435651673703, 46.79169312301091
# 22864, 42.77549204282873, 43.817411914098734
# 22909, 45.81399476269483, 46.95321227074243
# 22910, 44.90025599047384, 45.07138393394037
# 22911, 44.25432586708, 44.61914891428333
# 22912, 44.83902214782546, 45.349675784626506
# 22913, 45.6279309592198, 45.87777565094545
# 22914, 41.490786695557134, 42.591853721677914
# 22915, 39.52634131693877, 42.070237453569966
# 22916, 37.148854464394795, 39.28664254806311
# 22917, 36.20723048582355, 36.79705896866904
# 22920, 62.73571881650874, 64.42266138021803
# 22921, 63.91172853417147, 66.29696830617542
# 22927, 44.253619110777734, 44.68499218424945
# 22928, 44.70723179731302, 45.783634292703226
# 22929, 45.30042071470723, 46.778207076836395
# 22930, 47.50060653583, 49.447419582505674
# 22931, 48.9590644795, 50.638180242619406
# 22944, 12.94149341897446, 16.728488114164875
# 22945, 16.318798103446184, 20.368723008998117
# 22946, 21.126732170682388, 22.99246526490542
# 22947, 14.882288066220625, 16.015950646849163
# 22948, 16.819835707048966, 20.50903994423176
# 22949, 49.236293381062254, 50.18535721042741
# 22950, 47.90280958888393, 48.68997088850489
# 22951, 47.75636328104075, 48.456795065965906
# 22952, 46.99454908511689, 47.040652927950006
# 23007, 34.10586794374307, 34.33339297486047
# 23008, 33.67132954683322, 33.8077694788604
# 23030, 34.120086902602516, 34.34955576209084
# 23031, 33.67142867823, 33.740869810890565
# 23032, 34.460913486362244, 34.88574907534703
# 23033, 7.558914052457496, 8.408154307398604
# 23034, 7.518991736067065, 8.869987889144255
# 23035, 8.385625733731246, 11.413449800701258
# 23036, 11.969727053362533, 15.71649602959802
# 23037, 15.262404888367826, 19.302347577334857
# 23038, 20.133770031248318, 24.344217548324096
# 23039, 23.749441938593648, 26.012675866949557
# 23040, 26.961167293510094, 31.21903175199732
# 23041, 45.86685999515759, 46.637406677859616
# 23042, 46.86543307470641, 48.56060458978087
# 23043, 48.039741783788784, 50.009957670173975
# 23053, 12.568166494289741, 13.6317878822302
# 23054, 34.87464869600812, 34.90051795146766
# 23055, 34.36739174507598, 34.40937851167418
# 23056, 34.553673331078706, 35.3087464496329
# 23057, 7.916252687714831, 8.328794826465455
# 23058, 7.861130618634576, 9.734166095648902
# 23059, 11.540018859432891, 13.17091771541321
# 23060, 14.610301234010521, 16.491364872601082
# 23073, 38.81569160106077, 40.59004106653883
# 23074, 41.25686355054011, 42.75627943141333
# 23078, 48.9527104869295, 49.10807746670462
# 23079, 48.30651045865394, 48.84812164103554
# 23080, 47.680903970380655, 47.832146849141644
# 23081, 47.30867822792688, 47.58799813355958
# 23082, 47.16623623584631, 47.24177624595065
# 23083, 47.13982773348305, 47.713120176992625
# 23084, 46.03250266071791, 46.38526031829087
# 23094, 8.847847495234248, 9.843255569614328
# 23095, 10.667263770116065, 12.937203461592219
# 23098, 29.63611174563527, 30.36517039218399

# %% [markdown]
# # NSB level

# %%
run_ids_str = [str(rid) for rid in run_ids_list]

plt.figure(figsize=(10, 5))
plt.scatter(run_ids_str, nsb_values, color="black")
plt.axhline(y=1.75, color="green", linestyle="--")
plt.axhline(y=2.25, color="green", linestyle="--")
plt.ylim(0 ,3)

plt.xlabel("Run ID")
plt.ylabel("NSB")
plt.title("NSB per Run ID")
plt.grid(True, axis="y")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
print("Runs with nsb <= 1.75 (DARK)")
print(runs_dark_nsb)
print()
print("Runs with nsb > 1.75 and <= 2.25 (MEDIUM)")
print(runs_medium_nsb)
print()
print("Runs with nsb > 2.25 and < 3.0 (BRIGHT)")
print(runs_bright_nsb)
# Out:
# Runs with nsb <= 1.75 (DARK)
# [11431, 11430, 11433, 11434, 11432, 11463, 11466, 11464, 11465, 11468, 11469, 11467, 11470, 16745, 16746, 16749, 16750, 16744, 16748, 16747, 16737, 16736, 16739, 16740, 23098, 22824, 22821, 22822, 22820, 22823, 22833, 22835, 22834, 22909, 22950, 22949, 22952, 22951, 23084, 23082, 23080, 23081, 23078, 23079, 23083, 23059, 23060, 23057, 23058, 22946, 22945, 22944, 23037, 23036, 23033, 23038, 23034, 23035, 22910, 22911, 22912, 22913, 23055, 23056, 23054, 23008, 23007, 23030, 23031, 23032, 22863, 22858, 22862, 22860, 22864, 22859, 22861, 22914, 22915, 22917, 22916, 23074, 23073, 22948, 22947, 23040, 23095]
#
# Runs with nsb > 1.75 and <= 2.25 (MEDIUM)
# [11481, 11479, 11482, 11480, 22921, 22920, 23053, 23041, 23043, 23042, 22927, 22928, 22929, 22827, 23039, 23094]
#
# Runs with nsb > 2.25 and < 3.0 (BRIGHT)
# [22931, 22930, 22826, 22825]
